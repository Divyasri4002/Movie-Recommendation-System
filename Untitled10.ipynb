# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Step 1: Load the Dataset
file_path = '/content/gretel_generated_table_2024-09-09-09-22-41.csv'  # Replace with your actual file path
movie_data = pd.read_csv(file_path)

# Display the first few rows of the dataset
print("Sample of the dataset:")
print(movie_data.head())

# Display the column names of the dataset
print("\nColumn names in the dataset:")
print(movie_data.columns)

# Check column names and adjust code if necessary
def get_column_name(df, expected_name):
    for col in df.columns:
        if col.strip().lower() == expected_name.strip().lower():
            return col
    raise KeyError(f"Column '{expected_name}' not found in the dataset.")

# Step 2: Movie Details by Name
def view_movie_details(movie_name):
    movie_title_col = get_column_name(movie_data, 'Movie title')
    rating_col = get_column_name(movie_data, 'Rating')
    genre_col = get_column_name(movie_data, 'Genre')
    review_col = get_column_name(movie_data, 'Review')

    movie = movie_data[movie_data[movie_title_col].str.contains(movie_name, case=False, na=False)]
    if not movie.empty:
        for index, row in movie.iterrows():
            print(f"\nDetails for '{row[movie_title_col]}':")
            print(f"Rating: {row[rating_col]}/10")
            print(f"Genre: {row[genre_col]}")
            print(f"Review: {row[review_col]}")
    else:
        print(f"'{movie_name}' not found in the dataset.")

# Step 3: List Movies by Year
def list_movies_by_year(year):
    year_col = get_column_name(movie_data, 'Year')
    movie_title_col = get_column_name(movie_data, 'Movie title')

    movies = movie_data[movie_data[year_col] == year]
    if not movies.empty:
        print(f"\nMovies released in {year}:")
        print(movies[[movie_title_col]])
    else:
        print(f"No movies found for the year {year}.")

# Step 4: Table Chart with Movie and Director
def plot_movie_director_table():
    movie_title_col = get_column_name(movie_data, 'Movie title')
    director_col = get_column_name(movie_data, 'Director')

    plt.figure(figsize=(12, 8))
    movie_director_df = movie_data[[movie_title_col, director_col]].drop_duplicates()
    movie_director_df = movie_director_df.reset_index(drop=True)
    ax = plt.gca()
    ax.axis('off')
    table = plt.table(cellText=movie_director_df.values,
                      colLabels=movie_director_df.columns,
                      cellLoc='center',
                      loc='center')
    plt.title('Movie and Director')
    plt.show()

# Step 5: Treemap for Movie vs Highest Gross
def plot_movie_highest_gross_treemap():
    movie_title_col = get_column_name(movie_data, 'Movie title')
    highest_gross_col = get_column_name(movie_data, 'Highest Gross')

    highest_gross_df = movie_data[[movie_title_col, highest_gross_col]]
    highest_gross_df[highest_gross_col] = pd.to_numeric(highest_gross_df[highest_gross_col], errors='coerce')
    highest_gross_df = highest_gross_df.dropna()

    fig = px.treemap(highest_gross_df,
                     path=[movie_title_col],
                     values=highest_gross_col,
                     color=highest_gross_col,
                     color_continuous_scale='viridis',
                     title='Movies vs Highest Gross Treemap')
    fig.show()

# Step 6: Line Chart for Movie vs Rating
def plot_movie_rating_line_chart():
    movie_title_col = get_column_name(movie_data, 'Movie title')
    rating_col = get_column_name(movie_data, 'Rating')

    plt.figure(figsize=(14, 7))
    movie_rating_df = movie_data[[movie_title_col, rating_col]]
    movie_rating_df[rating_col] = pd.to_numeric(movie_rating_df[rating_col], errors='coerce')
    movie_rating_df = movie_rating_df.dropna()

    # Sorting the DataFrame for better line chart plotting
    movie_rating_df = movie_rating_df.sort_values(by=rating_col, ascending=False)

    plt.plot(movie_rating_df[movie_title_col], movie_rating_df[rating_col], marker='o', linestyle='-', color='b')
    plt.xticks(rotation=90)  # Rotate movie titles for better readability
    plt.xlabel('Movie Title')
    plt.ylabel('Rating')
    plt.title('Movies vs Rating Line Chart')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

# Interactive User Input
def interactive_menu():
    while True:
        print("\nInteractive Menu:")
        print("1. View Movie Details by Name")
        print("2. List Movies by Year")
        print("3. Plot Movie vs Director Table")
        print("4. Plot Treemap for Movie vs Highest Gross")
        print("5. Plot Line Chart for Movie vs Rating")
        print("6. Exit")

        choice = input("Enter your choice (1-6): ")

        if choice == '1':
            movie_name = input("Enter the movie name: ")
            view_movie_details(movie_name)
        elif choice == '2':
            try:
                year = int(input("Enter the year: "))
                list_movies_by_year(year)
            except ValueError:
                print("Invalid year. Please enter a numeric value.")
        elif choice == '3':
            plot_movie_director_table()
        elif choice == '4':
            plot_movie_highest_gross_treemap()
        elif choice == '5':
            plot_movie_rating_line_chart()
        elif choice == '6':
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please enter a number between 1 and 6.")

# Run interactive menu
interactive_menu()
# Out:
# Sample of the dataset:
#               Movie title  Rating                      Genre  \
# 0  A Song of Ice and Fire     8.5                    Fantasy
# 1           The Lost City     7.8  Action, Adventure, Comedy
# 2     The Seven Year Itch     7.5            Romantic Comedy
# 3            The Eternals     8.0                  Superhero
# 4     The French Dispatch     7.5                     Comedy
#
#                                               Review  Year        Director  \
# 0  The plot is engaging and the characters are we...  2023  J.R.R. Tolkien
# 1  The Lost City is a thrilling adventure that ta...  2022    Adam Wingard
# 2  Tom Ewell plays Richard Sherman, a man who dev...  1955    Billy Wilder
# 3  The Eternals is a visually stunning film that ...  2021      Chloé Zhao
# 4  The French Dispatch is a witty and visually st...  2021    Wes Anderson
#
#    Highest Gross
# 0   2.000000e+09
# 1   1.500000e+07
# 2   1.150000e+07
# 3   1.500000e+07
# 4   1.200000e+07
#
# Column names in the dataset:
# Index(['Movie title', 'Rating', 'Genre', 'Review', 'Year', 'Director',
#        'Highest Gross'],
#       dtype='object')
#
# Interactive Menu:
# 1. View Movie Details by Name
# 2. List Movies by Year
# 3. Plot Movie vs Director Table
# 4. Plot Treemap for Movie vs Highest Gross
# 5. Plot Line Chart for Movie vs Rating
# 6. Exit
# Enter your choice (1-6): 4
# <ipython-input-3-567564a8aaaa>:77: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ba3c3ef9-f778-45d0-91e6-a3a5b0da3932" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba3c3ef9-f778-45d0-91e6-a3a5b0da3932")) {                    Plotly.newPlot(                        "ba3c3ef9-f778-45d0-91e6-a3a5b0da3932",                        [{"branchvalues":"total","customdata":[[1000000.0],[2000000000.0],[18000000.0],[31720421.7536071],[677000000.0],[900000.0],[1300000.0],[16000000.0],[16200000.0],[204000000.0],[21300000.0],[12000000.0],[96000000.0],[32000000.0],[12000000.0],[900000.0],[977125000.0],[1200000000.0],[15000000.0],[12000000.0],[24500000.0],[1000000000.0],[50000000.0],[120000000.0],[18.3],[26100000.0],[170000000.0],[15000000.0],[10000000.0],[22000000.0],[30000000.0],[13000000.0],[5000000.0],[13307692.307692308],[20000000.0],[500000.0],[8000000.0],[1612393203.883495],[91000000.0],[22000000.0],[876000000.0],[378000000.0],[926000000.0],[141666666.66666666],[1800000.0],[18000000.0],[9000000.0],[10000000.0],[13000000.0],[438193482.68839103],[12000000.0],[15110000.0],[10000000.0],[1000000.0],[1152173.9130434783],[20000000.0],[48070225.30862736],[20000000.0],[24000000.0],[1100000.0],[14000000.0],[11500000.0],[1642679.0],[45642339.373970345],[26613533.834586468],[15000000.0],[16636363.636363637],[32000000.0],[999987.5003124961],[22000000.0],[12000000.0],[28000000.0],[1200000.0],[3000000.0],[20000000.0]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eHighest Gross_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eHighest Gross=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["12 Angry Men","A Song of Ice and Fire","CODA","Dune","Forrest Gump","Girl with a Pearl Earring","Guernica","Last Night in Soho","One Flew Over the Cuckoo's Nest","Parasite","Pulp Fiction","Sakura Dreams","Schindler's List","The Adventures of Sharkboy and Lavagirl","The Alchemist's Daughter","The Birth of Venus","The Dark Knight","The Dark Knight Rises","The Eternals","The French Dispatch","The Godfather","The Golden Child","The Golden Dragon","The Golden Lotus","The Golden Voyage of Sinbad","The Good, the Bad and the Ugly","The Grand Budapest Hotel","The Hand of God","The Hidden City","The Infinite Loop","The Infinite Loop 2","The Last Goodbye","The Last Guardian","The Last Hope","The Last Hope 2","The Last Leaf","The Last Love Letter","The Last Samurai","The Last of Us","The Lord of the Rings","The Lord of the Rings: The Fellowship of the Ring","The Lord of the Rings: The Return of the King","The Lord of the Rings: The Two Towers","The Lost City","The Lost City of Z","The Lost Daughter","The Lost Expedition","The Lost Generation","The Lost Generation 2","The Matrix","The Memory of Water","The Name of the Rose","The Name of the Wind","The Night Caf\u00e9","The Persistence of Memory","The Power of the Dog","The Princess Bride","The Quantum Prophecy","The Quantum Prophecy 2","The Scream","The Secret Garden","The Seven Year Itch","The Seventh Seal","The Shawshank Redemption","The Silence of the Lambs","The Star of India","The Starlight Serenade","The Starlight Serenade 2","The Starry Night","The Tragedy of Macbeth","The Unseen Ocean","The Unseen Ocean 2","The Weeping Woman","The Wizard of Oz","The Worst Person in the World"],"labels":["12 Angry Men","A Song of Ice and Fire","CODA","Dune","Forrest Gump","Girl with a Pearl Earring","Guernica","Last Night in Soho","One Flew Over the Cuckoo's Nest","Parasite","Pulp Fiction","Sakura Dreams","Schindler's List","The Adventures of Sharkboy and Lavagirl","The Alchemist's Daughter","The Birth of Venus","The Dark Knight","The Dark Knight Rises","The Eternals","The French Dispatch","The Godfather","The Golden Child","The Golden ...
# Interactive Menu:
# 1. View Movie Details by Name
# 2. List Movies by Year
# 3. Plot Movie vs Director Table
# 4. Plot Treemap for Movie vs Highest Gross
# 5. Plot Line Chart for Movie vs Rating
# 6. Exit
# Enter your choice (1-6): 1
# Enter the movie name: 2
#
# Details for 'The Unseen Ocean 2':
# Rating: 8.6/10
# Genre: Documentary
# Review: The Unseen Ocean 2 is a sequel to the original documentary, taking viewers on a deeper dive into the ocean's depths. The film's cinematography is breathtaking, with stunning visuals that showcase the incredible diversity of marine life. The documentary also highlights the importance of ocean conservation and the impact of human activities on marine ecosystems. Overall, The Unseen Ocean 2 is a must-see for anyone interested in the natural world and the importance of preserving our planet's oceans.
#
# Details for 'The Quantum Prophecy 2':
# Rating: 8.3/10
# Genre: Science Fiction
# Review: The Quantum Prophecy 2 is a thought-provoking science fiction film that explores the possibilities of a world where quantum physics has the power to manipulate reality. The film's visuals are stunning, with impressive special effects that bring the concept to life. The cast, including Chris Evans and Scarlett Johansson, deliver strong performances, bringing depth and nuance to their characters. The film's story is also engaging, with a unique and imaginative take on the science fiction genre.
#
# Details for 'The Last Hope 2':
# Rating: 7.9/10
# Genre: Drama
# Review: The Last Hope 2 is a drama that follows a group of people as they try to survive in a world that has been ravaged by climate change. The film's visuals are stunning, with breathtaking vistas of a desolate and barren landscape. The cast, including Leonardo DiCaprio and Meryl Streep, deliver strong performances, bringing depth and emotion to their characters. The film's story is also engaging, with a unique and thought-provoking take on the drama genre.
#
# Details for 'The Infinite Loop 2':
# Rating: 9.0/10
# Genre: Thriller
# Review: The Infinite Loop 2 is a gripping thriller that follows a group of people as they try to escape a mysterious time loop. The film's visuals are stunning, with impressive action sequences and suspenseful moments. The cast, including Tom Hiddleston and Emma Stone, deliver strong performances, bringing depth and nuance to their characters. The film's story is also engaging, with a unique and imaginative take on the thriller genre.
#
# Details for 'The Lost Generation 2':
# Rating: 7.6/10
# Genre: Comedy
# Review: The Lost Generation 2 is a comedy that follows a group of young people as they navigate the challenges of growing up. The film's visuals are colorful and vibrant, with a fun and upbeat tone. The cast, including Zendaya and Noah Centineo, deliver strong performances, bringing humor and charm to their characters. The film's story is also engaging, with a unique and lighthearted take on the comedy genre.
#
# Details for 'The Starlight Serenade 2':
# Rating: 9.5/10
# Genre: Romance
# Review: The Starlight Serenade 2 is a romantic drama that follows a young musician as he falls in love with a woman from a different world. The film's cinematography is beautiful, with stunning visuals that capture the magic of the night sky. The cast, including Timothée Chalamet and Elle Fanning, deliver strong performances, bringing depth and emotion to their characters. The film's story is also engaging, with a unique and imaginative take on the romance genre.
#
# Details for '12 Angry Men':
# Rating: 9.0/10
# Genre: Drama
# Review: 12 Angry Men is a gripping and thought-provoking film that explores the complexities of human nature. The movie's themes of justice and morality are timeless and universal.
#
# Interactive Menu:
# 1. View Movie Details by Name
# 2. List Movies by Year
# 3. Plot Movie vs Director Table
# 4. Plot Treemap for Movie vs Highest Gross
# 5. Plot Line Chart for Movie vs Rating
# 6. Exit
# Enter your choice (1-6): 2
# Enter the year: 2021
#
# Movies released in 2021:
#                       Movie title
# 3                    The Eternals
# 4             The French Dispatch
# 5                            CODA
# 6            The Power of the Dog
# 7                            Dune
# 8          The Tragedy of Macbeth
# 9              Last Night in Soho
# 10              The Lost Daughter
# 11                The Hand of God
# 12  The Worst Person in the World
# 13                           CODA
# 14           The Power of the Dog
# 15                           Dune
# 16         The Tragedy of Macbeth
# 17             Last Night in Soho
# 18              The Lost Daughter
# 19                The Hand of God
# 20  The Worst Person in the World
# 79          The Lord of the Rings
# 85                           Dune
#
# Interactive Menu:
# 1. View Movie Details by Name
# 2. List Movies by Year
# 3. Plot Movie vs Director Table
# 4. Plot Treemap for Movie vs Highest Gross
# 5. Plot Line Chart for Movie vs Rating
# 6. Exit
# Enter your choice (1-6): 3
# Interactive Menu:
# 1. View Movie Details by Name
# 2. List Movies by Year
# 3. Plot Movie vs Director Table
# 4. Plot Treemap for Movie vs Highest Gross
# 5. Plot Line Chart for Movie vs Rating
# 6. Exit
# Enter your choice (1-6): 4
# <ipython-input-3-567564a8aaaa>:77: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b946f35d-66ee-4076-9c62-f730e52d23a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b946f35d-66ee-4076-9c62-f730e52d23a8")) {                    Plotly.newPlot(                        "b946f35d-66ee-4076-9c62-f730e52d23a8",                        [{"branchvalues":"total","customdata":[[1000000.0],[2000000000.0],[18000000.0],[31720421.7536071],[677000000.0],[900000.0],[1300000.0],[16000000.0],[16200000.0],[204000000.0],[21300000.0],[12000000.0],[96000000.0],[32000000.0],[12000000.0],[900000.0],[977125000.0],[1200000000.0],[15000000.0],[12000000.0],[24500000.0],[1000000000.0],[50000000.0],[120000000.0],[18.3],[26100000.0],[170000000.0],[15000000.0],[10000000.0],[22000000.0],[30000000.0],[13000000.0],[5000000.0],[13307692.307692308],[20000000.0],[500000.0],[8000000.0],[1612393203.883495],[91000000.0],[22000000.0],[876000000.0],[378000000.0],[926000000.0],[141666666.66666666],[1800000.0],[18000000.0],[9000000.0],[10000000.0],[13000000.0],[438193482.68839103],[12000000.0],[15110000.0],[10000000.0],[1000000.0],[1152173.9130434783],[20000000.0],[48070225.30862736],[20000000.0],[24000000.0],[1100000.0],[14000000.0],[11500000.0],[1642679.0],[45642339.373970345],[26613533.834586468],[15000000.0],[16636363.636363637],[32000000.0],[999987.5003124961],[22000000.0],[12000000.0],[28000000.0],[1200000.0],[3000000.0],[20000000.0]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003eHighest Gross_sum=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003eHighest Gross=%{color}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["12 Angry Men","A Song of Ice and Fire","CODA","Dune","Forrest Gump","Girl with a Pearl Earring","Guernica","Last Night in Soho","One Flew Over the Cuckoo's Nest","Parasite","Pulp Fiction","Sakura Dreams","Schindler's List","The Adventures of Sharkboy and Lavagirl","The Alchemist's Daughter","The Birth of Venus","The Dark Knight","The Dark Knight Rises","The Eternals","The French Dispatch","The Godfather","The Golden Child","The Golden Dragon","The Golden Lotus","The Golden Voyage of Sinbad","The Good, the Bad and the Ugly","The Grand Budapest Hotel","The Hand of God","The Hidden City","The Infinite Loop","The Infinite Loop 2","The Last Goodbye","The Last Guardian","The Last Hope","The Last Hope 2","The Last Leaf","The Last Love Letter","The Last Samurai","The Last of Us","The Lord of the Rings","The Lord of the Rings: The Fellowship of the Ring","The Lord of the Rings: The Return of the King","The Lord of the Rings: The Two Towers","The Lost City","The Lost City of Z","The Lost Daughter","The Lost Expedition","The Lost Generation","The Lost Generation 2","The Matrix","The Memory of Water","The Name of the Rose","The Name of the Wind","The Night Caf\u00e9","The Persistence of Memory","The Power of the Dog","The Princess Bride","The Quantum Prophecy","The Quantum Prophecy 2","The Scream","The Secret Garden","The Seven Year Itch","The Seventh Seal","The Shawshank Redemption","The Silence of the Lambs","The Star of India","The Starlight Serenade","The Starlight Serenade 2","The Starry Night","The Tragedy of Macbeth","The Unseen Ocean","The Unseen Ocean 2","The Weeping Woman","The Wizard of Oz","The Worst Person in the World"],"labels":["12 Angry Men","A Song of Ice and Fire","CODA","Dune","Forrest Gump","Girl with a Pearl Earring","Guernica","Last Night in Soho","One Flew Over the Cuckoo's Nest","Parasite","Pulp Fiction","Sakura Dreams","Schindler's List","The Adventures of Sharkboy and Lavagirl","The Alchemist's Daughter","The Birth of Venus","The Dark Knight","The Dark Knight Rises","The Eternals","The French Dispatch","The Godfather","The Golden Child","The Golden ...
# Interactive Menu:
# 1. View Movie Details by Name
# 2. List Movies by Year
# 3. Plot Movie vs Director Table
# 4. Plot Treemap for Movie vs Highest Gross
# 5. Plot Line Chart for Movie vs Rating
# 6. Exit
# Enter your choice (1-6): 5
# <ipython-input-3-567564a8aaaa>:95: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Interactive Menu:
# 1. View Movie Details by Name
# 2. List Movies by Year
# 3. Plot Movie vs Director Table
# 4. Plot Treemap for Movie vs Highest Gross
# 5. Plot Line Chart for Movie vs Rating
# 6. Exit
# Enter your choice (1-6): 6
# Exiting...
